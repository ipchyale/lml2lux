# %%
import pandas as pd

# %%
db = pd.read_csv('/Users/damoncrockett/lml2lux/sources/export_07_08_24.csv', encoding='latin-1')

# %%
db.loc[db['Catalog Number']==294]
# Out:
#          PhotoID  Year  DateUncertain  Catalog Number  \
# 3227  1000309450  1952              0             294
# 3228  1374686728  1952              0             294
# 3229 -1630616714  1952              0             294
# 3230  1346006676  1952              0             294
# 3231  -410204446  1952              0             294
# 3232   -51510853  1952              0             294
# 3233  1394888672  1952              0             294
# 3234  1805728014  1952              0             294
# 3235  1108974455  1952              0             294
# 3236  1793932780  1952              0             294
# 3237  -799675779  1952              0             294
# 3238 -1106868742  1952              0             294
# 3239  1610885363  1952              0             294
# 3240  1531282616  1952              0             294
# 3241   376808537  1952              0             294
# 3242 -1114252890  1952              0             294
# ...
